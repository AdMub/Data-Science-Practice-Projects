# %% [markdown]
# ## **MongoDb with python Updating Json Documents**
#
# ### **Functions to Discuss**
#
# - pymongo.collection.Collection.update_one()
# - pymongo.collection.Collection.update_many()
# - pymongo.collection.Collection.replace_one()

# %%
# with mongodb atllas cloud
from urllib.parse import quote_plus
from pymongo import MongoClient

# Properly encode the password
username = "username"
password = quote_plus("<password>")  # becomes  'Abc%password' because of @

uri = f"mongodb+srv://{username}:{password}@dbpractice.7uz5kjl.mongodb.net/test"

client = MongoClient(uri)

# %%
import pymongo

client=pymongo.MongoClient('mongodb://127.0.0.1:27017')

mydb=client['Employee']
inventory=mydb.inventory

# %%
inventory.insert_many([
    {"item": "canvas",
     "qty": 100,
     "size": {"h": 28, "w": 35.5, "uom": "cm"},
     "status": "A"},
    {"item": "journal",
     "qty": 25,
     "size": {"h": 14, "w": 21, "uom": "cm"},
     "status": "A"},
    {"item": "mat",
     "qty": 85,
     "size": {"h": 27.9, "w": 35.5, "uom": "cm"},
     "status": "A"},
    {"item": "mousepad",
     "qty": 25,
     "size": {"h": 19, "w": 22.85, "uom": "cm"},
     "status": "P"},
    {"item": "notebook",
     "qty": 50,
     "size": {"h": 8.5, "w": 11, "uom": "in"},
     "status": "P"},
    {"item": "paper",
     "qty": 100,
     "size": {"h": 8.5, "w": 11, "uom": "in"},
     "status": "D"},
    {"item": "planner",
     "qty": 75,
     "size": {"h": 22.85, "w": 30, "uom": "cm"},
     "status": "D"},
    {"item": "postcard",
     "qty": 45,
     "size": {"h": 10, "w": 15.25, "uom": "cm"},
     "status": "A"},
    {"item": "sketchbook",
     "qty": 80,
     "size": {"h": 14, "w": 21, "uom": "cm"},
     "status": "A"},
    {"item": "sketch pad",
     "qty": 95,
     "size": {"h": 22.85, "w": 30.5, "uom": "cm"},
     "status": "A"}])
# Out:
# InsertManyResult([ObjectId('684d5efbe9f743dc62c03eb9'), ObjectId('684d5efbe9f743dc62c03eba'), ObjectId('684d5efbe9f743dc62c03ebb'), ObjectId('684d5efbe9f743dc62c03ebc'), ObjectId('684d5efbe9f743dc62c03ebd'), ObjectId('684d5efbe9f743dc62c03ebe'), ObjectId('684d5efbe9f743dc62c03ebf'), ObjectId('684d5efbe9f743dc62c03ec0'), ObjectId('684d5efbe9f743dc62c03ec1'), ObjectId('684d5efbe9f743dc62c03ec2')], acknowledged=True)

# %%
# Update in mongodb
# "$set" - replace, update, set some values
# "$currentDate" to specify the date, time, it is updated

inventory.update_one(
{"item":"sketch pad"},
{"$set":{"size.uom":"m","status":"P"},
"$currentDate":{"lastModified":True}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
inventory.update_one(
{"item":"postcard"},
{"$set":{"size.w":22.5,"status":"M"},
"$currentDate":{"lastModified":True}}
)
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
inventory.update_many(
    {"qty": {"$lt": 50}},
    {"$set": {"size.uom": "in", "status": "P"},
     "$currentDate": {"lastModified": True}})
# Out:
# UpdateResult({'n': 15, 'nModified': 15, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
inventory.replace_one(
    {"item": "
    paper"},
    {"item": "paper",
     "instock": [
         {"warehouse": "A", "qty": 60},
         {"warehouse": "B", "qty": 40}]})
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)
